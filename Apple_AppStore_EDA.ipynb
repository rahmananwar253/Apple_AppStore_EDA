# %% [markdown]
# # **Apple AppStore EDA**

# %% [markdown]
# ## About Author
# - Author :  Rahman Anwar
# - Date : 15/01/2024
# - Email : rahmananwar253@gmail.com
# - Github : [rahmananwar253](https://github.com/rahmananwar253)
# - Kaggle : [rahmananwar](https://www.kaggle.com/abdurrahmananwar)

# %% [markdown]
# ## About Dataset
#
# - Data: Apple App Store
# - Source: You can download from this [Link](https://www.kaggle.com/datasets/gauthamp10/apple-appstore-apps/code)

# %% [markdown]
# ## Objective
# The objective of EDA on the Apple App Store dataset is to gain insights, discover patterns, and obtain a deeper understanding of the data, which can inform decision-making, guide further analysis, or provide insights for business or research purposes related to the app ecosystem.

# %% [markdown]
# ## 1. Importing Libraries

# %% [markdown]
# We will use following libraries:
# - Pandas: A powerful data manipulation and analysis library that provides data structures and functions to efficiently work with structured data, such as tables or CSV files.
#
# - Matplotlib: A popular data visualization library that enables the creation of various types of plots and charts, allowing users to visualize and analyze their data in a clear and meaningful way.
#
# - NumPy: A fundamental library for numerical computing in Python that provides efficient handling of large, multi-dimensional arrays and a wide range of mathematical functions for array operations.
#
# - Seaborn: A Python data visualization library built on top of matplotlib that provides a high-level interface for creating attractive and informative statistical graphics, simplifying the process of creating complex visualizations.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#this is for jupyter notebook to show the plot in the notebook itself instead of opening a new window for the plot
# %matplotlib inline

# %% [markdown]
# ## 2. Load Dataset

# %%
df=pd.read_csv('appleAppData.csv')

# %%
df.head()
# Out:
#                              App_Id                 App_Name  \
# 0               com.hkbu.arc.apaper           A+ Paper Guide
# 1               com.dmitriev.abooks                  A-Books
# 2                    no.terp.abooks                  A-books
# 3          fr.antoinettefleur.Book1              A-F Book #1
# 4  com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4  https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0             4+  21993472.0                  8.0  2017-09-28T03:02:41Z
# ...

# %% [markdown]
# > **Note**: Some the output of notebook does not present the complete output, therefore we can increase the limit of columns view and row view by using these commands:

# %%
pd.set_option('display.max_columns', None) # this is to display all the columns in the dataframe
pd.set_option('display.max_rows', None) # this is to display all the rows in the dataframe')

# %%
# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 3. Analyze Data

# %% [markdown]
# ### 3.1 View the column names

# %% [markdown]
# - let's see the exact column names

# %%
# to check the columns in the dataframe
df.columns
# Out:
# Index(['App_Id', 'App_Name', 'AppStore_Url', 'Primary_Genre', 'Content_Rating',
#        'Size_Bytes', 'Required_IOS_Version', 'Released', 'Updated', 'Version',
#        'Price', 'Currency', 'Free', 'DeveloperId', 'Developer',
#        'Developer_Url', 'Developer_Website', 'Average_User_Rating', 'Reviews',
#        'Current_Version_Score', 'Current_Version_Reviews'],
#       dtype='object')

# %% [markdown]
# ### 3.2 View the shape of dataset

# %% [markdown]
# - let's have a look on the shape of the dataset

# %%
# to check the number of rows and columns in the dataframe
print(f"The dataframe has {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# The dataframe has 1230376 rows and 21 columns

# %% [markdown]
# ### 3.3 View the datatypes of all column

# %% [markdown]
# - Not enought , let's have a look on the columns and their data types

# %%
# check for data types of the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230376 entries, 0 to 1230375
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   App_Id                   1230376 non-null  object
#  1   App_Name                 1230375 non-null  object
#  2   AppStore_Url             1230376 non-null  object
#  3   Primary_Genre            1230376 non-null  object
#  4   Content_Rating           1230376 non-null  object
#  5   Size_Bytes               1230152 non-null  float64
#  6   Required_IOS_Version     1230376 non-null  object
#  7   Released                 1230373 non-null  object
#  8   Updated                  1230376 non-null  object
#  9   Version                  1230376 non-null  object
#  10  Price                    1229886 non-null  float64
#  11  Currency                 1230376 non-null  object
#  12  Free                     1230376 non-null  bool
# ...

# %% [markdown]
# ### 3.4 View the statistical summary

# %%
# have a look at statistical summary of the dataframe
df.describe()
# Out:
#          Size_Bytes         Price   DeveloperId  Average_User_Rating  \
# count  1.230152e+06  1.229886e+06  1.230376e+06         1.230376e+06
# mean   7.510857e+07  5.041264e-01  1.092869e+09         1.788387e+00
# std    2.318726e+08  6.869674e+00  4.090897e+08         2.154105e+00
# min    2.762800e+04  0.000000e+00  2.816565e+08         0.000000e+00
# 25%    2.041344e+07  0.000000e+00  7.381109e+08         0.000000e+00
# 50%    4.333158e+07  0.000000e+00  1.179711e+09         0.000000e+00
# 75%    8.365466e+07  0.000000e+00  1.471960e+09         4.333330e+00
# max    7.677945e+10  9.999900e+02  1.590233e+09         5.000000e+00
#
#             Reviews  Current_Version_Score  Current_Version_Reviews
# count  1.230376e+06           1.230376e+06             1.230376e+06
# mean   8.259478e+02           1.788387e+00             8.259478e+02
# std    5.016051e+04           2.154105e+00             5.016051e+04
# min    0.000000e+00           0.000000e+00             0.000000e+00
# ...

# %%
df.columns
# Out:
# Index(['App_Id', 'App_Name', 'AppStore_Url', 'Primary_Genre', 'Content_Rating',
#        'Size_Bytes', 'Required_IOS_Version', 'Released', 'Updated', 'Version',
#        'Price', 'Currency', 'Free', 'DeveloperId', 'Developer',
#        'Developer_Url', 'Developer_Website', 'Average_User_Rating', 'Reviews',
#        'Current_Version_Score', 'Current_Version_Reviews'],
#       dtype='object')

# %% [markdown]
# ### Observation 1

# %% [markdown]
# - The dataframe has 1230376 rows and 21 columns.
# - There are 07 numerical (one of them that is  is `DeveloperId` is not numerical data, Its a nominal type variables so we will change it into object datatype.), 01 Boolean, and 13 strings (02 are dates) fields in the dataset
# - `Released` and `Updated` as object data type but both are of date-time datatype. We will see it later.
# - The `Free` column have bool data type, we  convert into catgorical data type in the form of free or paid.

# %% [markdown]
# ## **4 Dealing with missing values**
# Dealing with the missing values is one of the most important part of the data wrangling process, we must deal with the missing values in order to get the correct insights from the data.

# %% [markdown]
# ### 4.1 Check number of missing values

# %% [markdown]
# - let's have a look on the missing values

# %%
# to check the number of missing values in each column
df.isnull().sum()
# Out:
# App_Id                          0
# App_Name                        1
# AppStore_Url                    0
# Primary_Genre                   0
# Content_Rating                  0
# Size_Bytes                    224
# Required_IOS_Version            0
# Released                        3
# Updated                         0
# Version                         0
# Price                         490
# Currency                        0
# Free                            0
# DeveloperId                     0
# Developer                       0
# Developer_Url                1109
# Developer_Website          643988
# Average_User_Rating             0
# Reviews                         0
# Current_Version_Score           0
# Current_Version_Reviews         0
# dtype: int64

# %%
# this will show the number of null values in each column in descending order
df.isnull().sum().sort_values(ascending=False)
# Out:
# Developer_Website          643988
# Developer_Url                1109
# Price                         490
# Size_Bytes                    224
# Released                        3
# App_Name                        1
# Free                            0
# Current_Version_Score           0
# Reviews                         0
# Average_User_Rating             0
# Developer                       0
# DeveloperId                     0
# App_Id                          0
# Currency                        0
# Version                         0
# Updated                         0
# Required_IOS_Version            0
# Content_Rating                  0
# Primary_Genre                   0
# AppStore_Url                    0
# Current_Version_Reviews         0
# dtype: int64

# %%
df.isnull().sum().sum() # this will show the total number of null values in the dataframe
# Out:
# 645815

# %% [markdown]
# ### 4.2 Percentage of missing values

# %%
(df.isnull().sum()/len(df) * 100).sort_values(ascending=False) # this will show the percentage of null values in each column
# Out:
# Developer_Website          52.340748
# Developer_Url               0.090135
# Price                       0.039825
# Size_Bytes                  0.018206
# Released                    0.000244
# App_Name                    0.000081
# Free                        0.000000
# Current_Version_Score       0.000000
# Reviews                     0.000000
# Average_User_Rating         0.000000
# Developer                   0.000000
# DeveloperId                 0.000000
# App_Id                      0.000000
# Currency                    0.000000
# Version                     0.000000
# Updated                     0.000000
# Required_IOS_Version        0.000000
# Content_Rating              0.000000
# Primary_Genre               0.000000
# AppStore_Url                0.000000
# Current_Version_Reviews     0.000000
# dtype: float64

# %% [markdown]
# ### 4.3 Visualize missing values

# %% [markdown]
# - Let's plot the missing values in the dataset

# %%
# To visualize the null values in the dataframe

# fig size
plt.figure(figsize=(16,6))
# plot the null values in each column
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# - let's plot the missing values by percentage

# %%
# make figure size
plt.figure(figsize=(16,6))
# plot the null values by their percentag in each column
missing_percentage=df.isnull().sum()/len(df)*100
missing_percentage.plot(kind='bar')
# add the labels
plt.xlabel('Columns')
plt.ylabel('Percentage')
plt.title('Percentage of Missing Values in each column')
# Out:
# Text(0.5, 1.0, 'Percentage of Missing Values in each column')

# %% [markdown]
# ### 4.4 Visualize missing values having less than 1%

# %% [markdown]
# - Let's plot the missing values other than '`Developer_website`' column
# - We have missing percentage columns other than '`Developer_website`' having less than one percent of missing values, we will plot them as follows:

# %%
# make figure size
plt.figure(figsize=(16,6))
# plot the null values by their percentag in each column
missing_percentage[missing_percentage < 1].plot(kind='bar')

# add the labels
plt.xlabel('Columns')
plt.ylabel('Percentage')
plt.title('Missing Values (%) in columns having less than 1% null values')
# Out:
# Text(0.5, 1.0, 'Missing Values (%) in columns having less than 1% null values')

# %% [markdown]
# ### Observation 2
# ---
# - We have 643988 missing values in the `'Developer_Website'` column, which is  52.34% of the total values in the column.
# - We have 1109 missing values in the `'Developer_Url'` column, which is 0.090% of the total values in the column.
# - We have 490 missing value in the `'Price'` column, which is 0.039% of the total values in the column.
# - We have 224 missing values in the `'Size_Bytes'` column, which is 0.018% of the total values in the column.
# - We have only 3 missing value in `Released`, column, which is 0.000244% of the total values in the column.App_Name
# - We have only 1 missing value in `App_Name`, column, which is 0.000081% of the total values in the column.

# %% [markdown]
# ### 4.5 Handling missing data
# - In the `Developer_website` column, we have 52% missing values.So, instead of imputing those missing values, we should remove this column.
# - if the percentage of missing values is high and you believe that the column will not provide meaningful insights, removing it is also an option.

# %%
# drop the developer_Website column as it is not required for our analysis
df.drop('Developer_Website', axis=1, inplace=True)

# %%
# Replace null values in `Developer_Url` column with "No_Url"
df['Developer_Url'].fillna('No_Url', inplace=True)

# %%
# Now we have to check missing values again
df.isnull().sum().sort_values(ascending=False).head()
# Out:
# Price         490
# Size_Bytes    224
# Released        3
# App_Name        1
# Free            0
# dtype: int64

# %% [markdown]
# ### 4.6 Imputing Missing Values

# %%
# to check where the `App_Name` is null 
df[df['App_Name'].isnull()]
# Out:
#                 App_Id App_Name  \
# 964888  se.promedia.NA      NaN
#
#                                              AppStore_Url Primary_Genre  \
# 964888  https://apps.apple.com/us/app/na/id449134868?uo=4          News
#
#        Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 964888             4+  19528704.0                  9.0  2011-08-08T11:45:30Z
#
#                      Updated Version  Price Currency  Free  DeveloperId  \
# 964888  2020-12-21T14:08:02Z   8.1.2    0.0      USD  True    449134871
#
#        Developer                                      Developer_Url  \
# 964888  Promedia  https://apps.apple.com/us/developer/promedia/i...
#
#         Average_User_Rating  Reviews  Current_Version_Score  \
# 964888                  5.0        1                    5.0
#
#         Current_Version_Reviews
# 964888                        1

# %%
# to check where `Released` is null
df[df['Released'].isnull()]
# Out:
#                                                App_Id  \
# 264853  com.ironhidegames.frontiers.universal.premium
# 836858                    com.redgamesco.transformers
# 919513    com.crayolallc.crayola-create-and-play-plus
#
#                             App_Name  \
# 264853    Kingdom Rush Frontiers TD+
# 836858  Transformers: Tactical Arena
# 919513      Crayola Create and Play+
#
#                                              AppStore_Url Primary_Genre  \
# 264853  https://apps.apple.com/us/app/kingdom-rush-fro...         Games
# 836858  https://apps.apple.com/us/app/transformers-tac...         Games
# 919513  https://apps.apple.com/us/app/crayola-create-a...         Games
#
#        Content_Rating  Size_Bytes Required_IOS_Version Released  \
# 264853            12+         NaN                 13.0      NaN
# 836858             9+         NaN               13.5.0      NaN
# 919513             4+         NaN                   13      NaN
#
# ...

# %% [markdown]
# ### Observation 3
# - `App_Name` with null is also not meaningful, so it is better to analyze or drop it
# - It is better to analyze all rows where `Released` has Nan values.
# - We have some null values in our data in both the `Price` and `size_columns`.We will remove the rows that have the same null values in both columns.
# - Analyze the missing values in the `price` column. If they are deemed useful, replace them; otherwise, remove the rows with those missing values.

# %%
# drop the rows where `App_Name` is null
df.dropna(subset=['App_Name'], inplace=True)

# %%
# Replace missing values in `Released` column with values in 'Updated' column 
df['Released'].fillna(df['Updated'], inplace=True)

# %%
# Now we have to check missing values again
df.isnull().sum().sort_values(ascending=False).head()
# Out:
# Price                    490
# Size_Bytes               224
# Currency                   0
# Current_Version_Score      0
# Reviews                    0
# dtype: int64

# %%
# this will show the number of rows having null values in `Size_Bytes` and `Price` columns and 0 in `Reviews` and `Current_Version_Score` columns
df[(df['Size_Bytes'].isnull()) & (df['Price'].isnull()) & (df['Reviews']==0) & (df['Current_Version_Score']==0)].shape
# Out:
# (85, 20)

# %%
# to check the shape of missing values in `Size_Bytes` column and also in `Price` column
len(df[(df['Size_Bytes'].isnull()) & (df['Price'].isnull())])
# Out:
# 224

# %%
# drop the null values in `size_bytes` column 
df.dropna(subset=['Size_Bytes'], inplace=True)

# %%
# Now we have to check missing values again
df.isnull().sum().sort_values(ascending=False).head()
# Out:
# Price                    266
# App_Name                   0
# Current_Version_Score      0
# Reviews                    0
# Average_User_Rating        0
# dtype: int64

# %%
# this will show the number of rows having null values in `Price` column and `Free` column having False value
df[(df['Price'].isnull()) & (df['Free'] == False)].shape
# Out:
# (266, 20)

# %%
# Drop the rows having null values in `Price` column and `Free` column having False value
df.dropna(subset=['Price'], inplace=True)

# %%
# Now we have to check missing values again
df.isnull().sum().sort_values(ascending=False)
# Out:
# App_Id                     0
# App_Name                   0
# Current_Version_Score      0
# Reviews                    0
# Average_User_Rating        0
# Developer_Url              0
# Developer                  0
# DeveloperId                0
# Free                       0
# Currency                   0
# Price                      0
# Version                    0
# Updated                    0
# Released                   0
# Required_IOS_Version       0
# Size_Bytes                 0
# Content_Rating             0
# Primary_Genre              0
# AppStore_Url               0
# Current_Version_Reviews    0
# dtype: int64

# %% [markdown]
# # **Milestone**
#  - *We clean our dataset from missing values*
#  - *We Deal with all null values properly*

# %% [markdown]
# ### Observation 4
# - App size is in bytes, to visualize properly we will convert it into Megabytes(MB)
# - We can also apply binning on `Content_Rating` and `Reviews`
# - Change column name from `Free` column to `Type` column and replace boolean values 'False' with 'Paid' and 'True' with 'Free'.
# - Convert Date column from UTC format to Standard Date format

# %% [markdown]
# ## 5 Feature Engineering

# %%
df['Released'] = pd.to_datetime(df['Released'], utc=True)
df['Updated'] = pd.to_datetime(df['Updated'], utc=True)

# %%
# change column name from `Size_Bytes` to `Size_MB`
df.rename(columns={'Size_Bytes':'Size_in_MB'}, inplace=True)

# %%
# convert size from bytes to MB
df['Size_in_MB'] = df['Size_in_MB'].apply(lambda x: x/(1024*1024))

# %%
df.head(2)
# Out:
#                 App_Id        App_Name  \
# 0  com.hkbu.arc.apaper  A+ Paper Guide
# 1  com.dmitriev.abooks         A-Books
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
#
#   Content_Rating  Size_in_MB Required_IOS_Version                  Released  \
# 0             4+   20.974609                  8.0 2017-09-28 03:02:41+00:00
# 1             4+   12.527344                 10.0 2015-08-31 19:31:32+00:00
#
#                     Updated Version  Price Currency  Free  DeveloperId  \
# 0 2018-12-21 21:30:36+00:00   1.1.2    0.0      USD  True   1375410542
# 1 2019-07-23 20:31:09+00:00     1.3    0.0      USD  True   1031572001
#
#         Developer                                      Developer_Url  \
# 0        HKBU ARC  https://apps.apple.com/us/developer/hkbu-arc/i...
# ...

# %%
# check unique values in `Free` column
df['Free'].unique()
# Out:
# array([ True, False])

# %%
# rename column `Free` to `Type`
df.rename(columns={'Free':'Type'}, inplace=True)
# replace `Free` with `Free App` and `Paid` with `Paid App`
df['Type'].replace({False:'Paid App', True:'Free App'}, inplace=True)

# %%
df.head(2)
# Out:
#                 App_Id        App_Name  \
# 0  com.hkbu.arc.apaper  A+ Paper Guide
# 1  com.dmitriev.abooks         A-Books
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
#
#   Content_Rating  Size_in_MB Required_IOS_Version                  Released  \
# 0             4+   20.974609                  8.0 2017-09-28 03:02:41+00:00
# 1             4+   12.527344                 10.0 2015-08-31 19:31:32+00:00
#
#                     Updated Version  Price Currency      Type  DeveloperId  \
# 0 2018-12-21 21:30:36+00:00   1.1.2    0.0      USD  Free App   1375410542
# 1 2019-07-23 20:31:09+00:00     1.3    0.0      USD  Free App   1031572001
#
#         Developer                                      Developer_Url  \
# 0        HKBU ARC  https://apps.apple.com/us/developer/hkbu-arc/i...
# ...

# %% [markdown]
# ### 5.1 Rename columns

# %%
# count unique values in `Content_Rating` column with values and count
df['Content_Rating'].value_counts()
# Out:
# Content_Rating
# 4+               980708
# 17+              124105
# 12+               89453
# 9+                35609
# Not yet rated        10
# Name: count, dtype: int64

# %%
# convert `content_rating` column into meaningful values 
df['Content_Rating'] = df['Content_Rating'].replace({'4+':'Kids', '9+': 'Children', '12+': 'Teen','17+': 'Adult', 'Not yet rated':'Everyone'})
df['Content_Rating'].value_counts()
# Out:
# Content_Rating
# Kids        980708
# Adult       124105
# Teen         89453
# Children     35609
# Everyone        10
# Name: count, dtype: int64

# %%
df['Content_Rating'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Content_Rating'>

# %%
# plot `content_rating` column with types
sns.countplot(x='Content_Rating', data=df, hue='Type')
plt.title('Content Rating vs Type')
# rotate the xticks
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Kids'),
#   Text(1, 0, 'Adult'),
#   Text(2, 0, 'Children'),
#   Text(3, 0, 'Teen'),
#   Text(4, 0, 'Everyone')])

# %%
# to check `Primary_genre`` column with values and count
df['Primary_Genre'].value_counts()
# Out:
# Primary_Genre
# Games                     193328
# Business                  128296
# Education                 119168
# Utilities                  94003
# Lifestyle                  84562
# Food & Drink               73155
# Health & Fitness           60717
# Productivity               59425
# Entertainment              53130
# Shopping                   49535
# Finance                    44981
# Travel                     43726
# Sports                     31455
# Music                      29895
# Medical                    27994
# Photo & Video              25953
# Social Networking          25420
# News                       20422
# Reference                  18614
# Navigation                 12636
# Stickers                   12407
# Book                       11472
# Weather                     3563
# Graphics & Design           2780
# Developer Tools             1951
# Magazines & Newspapers      1297
# Name: count, dtype: int64

# %%
# make a plot of `primary_genre` column with values and count
plt.figure(figsize=(16,6))
df['Primary_Genre'].value_counts().plot(kind='bar')
plt.title('Primary Genre vs Count')
# Out:
# Text(0.5, 1.0, 'Primary Genre vs Count')

# %%
#make a plot of `primary_genre` column with types and count
plt.figure(figsize=(16,6))
plt.xticks(rotation=90)
sns.countplot(x='Primary_Genre', data=df, hue='Type')
# Out:
# <Axes: xlabel='Primary_Genre', ylabel='count'>

# %% [markdown]
# ### 5.2 Binning

# %% [markdown]
# - let's make some changes to get useful insights from data

# %%
# to check minimum reviews in `Reviews` column
df['Reviews'].min()
# Out:
# 0

# %%
# to check maximum reviews in `Reviews` column
df['Reviews'].max()
# Out:
# 22685334

# %%
df.Reviews.describe()
# Out:
# count    1.229885e+06
# mean     8.260666e+02
# std      5.017049e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      3.000000e+00
# max      2.268533e+07
# Name: Reviews, dtype: float64

# %%
# making a new column called 'Reviews_category' which will have the category of the `Reviews`
bins = [-1, 0, 1_000, 10_000, 100_000, 1_000_000, 22_685_334]
labels=['No_Reviews', 'Low', 'Moderate', 'High', 'Very High', 'Top Notch']
df['Reviews_category'] = pd.cut(df['Reviews'], bins=bins, labels=labels)
df['Reviews_category'].value_counts()
# Out:
# Reviews_category
# No_Reviews    683969
# Low           521786
# Moderate       17111
# High            5658
# Very High       1209
# Top Notch        152
# Name: count, dtype: int64

# %% [markdown]
# ### 5.3 Duplicates
# * Removing duplicates is one of the most important part of the data wrangling process, we must remove the duplicates in order to get the correct insights from the data.
# * If you do not remove duplicates from a dataset, it can lead to incorrect insights and analysis.
# * Duplicates can skew statistical measures such as mean, median, and standard deviation, and can also lead to over-representation of certain data points.
# * It is important to remove duplicates to ensure the accuracy and reliability of your data analysis.

# %%
# find duplicate if any
df.duplicated().sum()
# Out:
# 0

# %%
# let's check for number of duplicates
for col in df.columns:
    print(f"Number of duplicates in {col} column are: {df[col].duplicated().sum()}")
# Out:
# Number of duplicates in App_Id column are: 0
# Number of duplicates in App_Name column are: 6862
# Number of duplicates in AppStore_Url column are: 0
# Number of duplicates in Primary_Genre column are: 1229859
# Number of duplicates in Content_Rating column are: 1229880
# Number of duplicates in Size_in_MB column are: 974106
# Number of duplicates in Required_IOS_Version column are: 1229626
# Number of duplicates in Released column are: 565159
# Number of duplicates in Updated column are: 34114
# Number of duplicates in Version column are: 1188629
# Number of duplicates in Price column are: 1229797
# Number of duplicates in Currency column are: 1229884
# Number of duplicates in Type column are: 1229883
# Number of duplicates in DeveloperId column are: 720685
# Number of duplicates in Developer column are: 724710
# Number of duplicates in Developer_Url column are: 715894
# Number of duplicates in Average_User_Rating column are: 1184870
# ...

# %% [markdown]
# >

# %% [markdown]
# > Note: There are many duplicate values in each column but if you check the column `App_Id` and `AppStore_Url` have o duplicate value, but other variables have multiple repeated values.

# %% [markdown]
# ### 5.4 Insights from data

# %% [markdown]
# -  Which category has the highest number of apps?

# %%
# which category has highest number of apps
df['Primary_Genre'].value_counts().head(10) # this will show the top 10 categories with highest number of apps
# Out:
# Primary_Genre
# Games               193328
# Business            128296
# Education           119168
# Utilities            94003
# Lifestyle            84562
# Food & Drink         73155
# Health & Fitness     60717
# Productivity         59425
# Entertainment        53130
# Shopping             49535
# Name: count, dtype: int64

# %% [markdown]
# - Which category has the highest number of reviews?

# %%
# Category with highest number of Reviews
df.groupby('Primary_Genre')['Reviews'].sum().sort_values(ascending=False).head(10)
# Out:
# Primary_Genre
# Games            258186751
# Finance           90502834
# Photo & Video     76764633
# Shopping          74140277
# Food & Drink      57859585
# Travel            52974311
# Music             51714248
# Entertainment     50540087
# Lifestyle         38850960
# Utilities         34417544
# Name: Reviews, dtype: int64

# %%
df.head(4)
# Out:
#                      App_Id        App_Name  \
# 0       com.hkbu.arc.apaper  A+ Paper Guide
# 1       com.dmitriev.abooks         A-Books
# 2            no.terp.abooks         A-books
# 3  fr.antoinettefleur.Book1     A-F Book #1
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
#
#   Content_Rating  Size_in_MB Required_IOS_Version                  Released  \
# 0           Kids   20.974609                  8.0 2017-09-28 03:02:41+00:00
# 1           Kids   12.527344                 10.0 2015-08-31 19:31:32+00:00
# 2           Kids   20.926758                  9.0 2021-04-14 07:00:00+00:00
# 3           Kids   78.059570                  8.0 2012-02-10 03:40:07+00:00
#
# ...

# %% [markdown]
# - Which category has the highest rating?

# %%
df.Average_User_Rating.value_counts().sort_index(ascending=False).head(10)
# Out:
# Average_User_Rating
# 5.00000    184277
# 4.99967         1
# 4.99934         1
# 4.99899         1
# 4.99874         1
# 4.99866         1
# 4.99864         2
# 4.99831         1
# 4.99821         1
# 4.99809         1
# Name: count, dtype: int64

# %%
# which category has the highest rating 
df.groupby('Primary_Genre')['Average_User_Rating'].mean().sort_values(ascending=False).head(10)
# Out:
# Primary_Genre
# Weather              2.594045
# Games                2.557332
# Photo & Video        2.306259
# Music                2.253994
# Book                 2.182049
# Reference            2.180238
# Finance              2.111061
# Entertainment        2.020944
# Social Networking    1.994556
# Health & Fitness     1.848943
# Name: Average_User_Rating, dtype: float64

# %%
# plot the rating distribution
plt.figure(figsize=(16, 6)) # make figure size
sns.kdeplot(df['Average_User_Rating'], color="blue", shade=True) # plot the distribution plot 
# add the labels
plt.title('Distribution of Average User Rating')
# Out:
# Text(0.5, 1.0, 'Distribution of Average User Rating')

# %% [markdown]
# ## **6 Questions and Answers:**

# %% [markdown]
# ##### 1. Which category has the highest average user rating?

# %%
# Which category has the highest average user rating?
df.groupby('Primary_Genre')['Average_User_Rating'].mean().sort_values(ascending=False).head(10)
# Out:
# Primary_Genre
# Weather              2.594045
# Games                2.557332
# Photo & Video        2.306259
# Music                2.253994
# Book                 2.182049
# Reference            2.180238
# Finance              2.111061
# Entertainment        2.020944
# Social Networking    1.994556
# Health & Fitness     1.848943
# Name: Average_User_Rating, dtype: float64

# %%
# plot the category with highest average user rating
plt.figure(figsize=(16,6))
df.groupby('Primary_Genre')['Average_User_Rating'].mean().sort_values(ascending=False).plot(kind='bar')

# add the label
plt.xlabel('Category')
plt.ylabel('Average User Rating')
plt.title('Category with highest average user rating')
# Out:
# Text(0.5, 1.0, 'Category with highest average user rating')

# %% [markdown]
# Figure-: Shows the Distribution of all Categories according to the User Ratings

# %% [markdown]
# ##### 2. What is the most common content rating in the dataset?

# %%
common_rating = df['Content_Rating'].mode().values[0]
print("Most common content rating:", common_rating)
# Out:
# Most common content rating: Kids

# %%
# plot the content rating distribution
plt.figure(figsize=(16,6))
sns.countplot(x='Content_Rating', data=df, hue='Type')
# rotate the xticks
plt.xticks(rotation=45)
# add the labels
plt.xlabel('Content Rating')
plt.ylabel('Count')
plt.title('Content Rating Distribution')
# Out:
# Text(0.5, 1.0, 'Content Rating Distribution')

# %% [markdown]
#  Figure:- This figure shows the distribution of content rating in paid and free apps

# %% [markdown]
# ##### 3. How many apps have been released in each year?

# %%
df['Year'] = pd.to_datetime(df['Released']).dt.year
year_counts = df['Year'].value_counts()
print("Number of apps released in each year:\n", year_counts)
# Out:
# Number of apps released in each year:
#  Year
# 2020    227705
# 2021    217904
# 2019    165697
# 2018    135059
# 2017    126356
# 2016    120352
# 2015     78661
# 2014     55321
# 2013     39427
# 2012     27945
# 2011     19476
# 2010     10949
# 2009      4381
# 2008       652
# Name: count, dtype: int64

# %%
# plot the number of apps released in each year
plt.figure(figsize=(16,6))
year_counts.plot(kind='bar')
#add xticks rotation
plt.xticks(rotation=45)
# add the labels
plt.xlabel('Year')
plt.ylabel('Number of Apps')
plt.title('Number of Apps released in each year')
# Out:
# Text(0.5, 1.0, 'Number of Apps released in each year')

# %% [markdown]
# Figure:- This figure shows that the number of apps released in 2020 is highest and in 2008 is lowest

# %% [markdown]
# ##### 4. What is the average number of reviews for apps in each content rating category?

# %%
avg_reviews_by_rating = df.groupby('Content_Rating')['Reviews'].mean()
print("Average number of reviews by content rating:\n", avg_reviews_by_rating)
# Out:
# Average number of reviews by content rating:
#  Content_Rating
# Adult        825.142267
# Children    1049.460221
# Everyone    1575.000000
# Kids         593.514109
# Teen        3287.901814
# Name: Reviews, dtype: float64

# %%
# plot the average number of reviews by content rating
plt.figure(figsize=(16,6))
avg_reviews_by_rating.plot(kind='bar')
#add xticks rotation
plt.xticks(rotation=45)
# add the labels
plt.xlabel('Content Rating')
plt.ylabel('Average Number of Reviews')
plt.title('Average Number of Reviews by Content Rating')
# Out:
# Text(0.5, 1.0, 'Average Number of Reviews by Content Rating')

# %% [markdown]
# Figure:- This shows that the average number of reviews is highest for the Teen category and lowest for the Kids category.

# %% [markdown]
# ##### 5. How many apps are of each type (free or paid)?

# %%
type_counts = df['Type'].value_counts()
print("Number of apps by type:\n", type_counts)
# Out:
# Number of apps by type:
#  Type
# Free App    1127383
# Paid App     102502
# Name: count, dtype: int64

# %%
# plot the number of apps by type
plt.figure(figsize=(16,6))
type_counts.plot(kind='bar', color=['brown', 'green']) 
#add xticks rotation
plt.xticks(rotation=45)
# add the labels
plt.xlabel('Type')
plt.ylabel('Number of Apps')
plt.title('Number of Apps by Type')
# add the text on the bars
for i, v in enumerate(type_counts):
    plt.text(i, v, str(v), ha='center', va='bottom')

# %% [markdown]
# Figure:- This figure shows that there are more free apps than paid apps in the dataset.

# %% [markdown]
# ##### 6. What are the Top 5 Paid Apps based with highest ratings?

# %%
# plot the top 5 paid apps with highest number of reviews
plt.figure(figsize=(16,6))
df[df['Type']=='Paid App'].groupby('App_Name')['Reviews'].sum().sort_values(ascending=False).head(5).plot(kind='bar')
#add xticks rotation
plt.xticks(rotation=45)
# add the labels
plt.xlabel('App Name')
plt.ylabel('Number of Reviews')
plt.title('Top 5 Paid Apps with Highest Number of Reviews')
# add the text on the bars
for i, v in enumerate(df[df['Type']=='Paid App'].groupby('App_Name')['Reviews'].sum().sort_values(ascending=False).head(5)):
    plt.text(i, v, str(v), ha='center', va='bottom')

# %% [markdown]
# Figure:- This figure show the top 5 paid apps with highest number of reviews

# %% [markdown]
# ##### 7. What are the Top 5 free Apps based with highest ratings?

# %%
# plot the top 5 free apps with highest number of reviews
plt.figure(figsize=(16,6))
df[df['Type']=='Free App'].groupby('App_Name')['Reviews'].sum().sort_values(ascending=False).head(5).plot(kind='bar')
#add xticks rotation
plt.xticks(rotation=45)
# add the labels
plt.xlabel('App Name')
plt.ylabel('Number of Reviews')
plt.title('Top 5 Free Apps with Highest Number of Reviews')
# add the text on the bars
for i, v in enumerate(df[df['Type']=='Free App'].groupby('App_Name')['Reviews'].sum().sort_values(ascending=False).head(5)):
    plt.text(i, v, str(v), ha='center', va='bottom')

# %% [markdown]
# Figure:- This figure shows that the top 5 free apps have more number of reviews than the top 5 paid apps

# %% [markdown]
# ##### 8. List the top 5 developers based on the number of apps they have developed?

# %%
# list of top 5 developers with highest number of apps
top_5_developers = df['Developer'].value_counts().head(5)
print("Top 10 developers with highest number of apps:\n", top_5_developers)
# Out:
# Top 10 developers with highest number of apps:
#  Developer
# ChowNow                   3966
# Touch2Success             1649
# Alexander Velimirovic     1506
# MINDBODY, Incorporated    1247
# Phorest                   1131
# Name: count, dtype: int64

# %%
# plot the top 5 developers with highest number of apps
plt.figure(figsize=(16,6))
df['Developer'].value_counts().head(5).plot(kind='bar')
plt.xticks(rotation=45)

plt.title('Top 10 Developers with highest number of apps')
plt.xlabel('Developers')
plt.ylabel('Number of Apps')
# add the text on the bars
for i, v in enumerate(df['Developer'].value_counts().head(5)):
    plt.text(i, v, str(v), ha='center', va='bottom')

# %% [markdown]
# Figure:- This figure shows the top developers with their number of apps.
